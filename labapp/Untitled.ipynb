# %%
import pandas as pd
d = pd.read_csv("/Users/abnousa/data/chia_feng/overlapped_interactions/wt31_wt32.bedpe", sep = "\t")
d.head()
# Out:
#    chr1     start1       end1  chr2     start2       end2  count   expected  \
# 0  chr1   10000000   10010000  chr1   10080000   10090000     23  11.019127
# 1  chr1   10000000   10010000  chr1   10090000   10100000     58  28.017143
# 2  chr1  100000000  100010000  chr1  100100000  100110000     40  19.116817
# 3  chr1  100000000  100010000  chr1  100110000  100120000     60  29.653410
# 4  chr1  100000000  100010000  chr1  100160000  100170000     22   6.745002
#
#         fdr ClusterLabel       ...        ClusterNegLog10P ClusterSummit  \
# 0  0.009136      chr1_45       ...               25.096923             0
# 1  0.000011      chr1_45       ...               25.096923             0
# 2  0.000312     chr1_459       ...               40.683478             0
# 3  0.000015     chr1_459       ...               40.683478             0
# 4  0.000032     chr1_460       ...               28.524753             0
#
# ...

# %%
dict(dict(d.T)[0])
# Out:
# {'ClusterLabel': 'chr1_45',
#  'ClusterLabel.2': 'chr1_38',
#  'ClusterNegLog10P': 25.096923190721103,
#  'ClusterNegLog10P.2': 19.724895759686998,
#  'ClusterSize': 4,
#  'ClusterSize.2': 3,
#  'ClusterSummit': 0,
#  'ClusterSummit.2': 0,
#  'ClusterType': 'SharpPeak',
#  'ClusterType.2': 'SharpPeak',
#  'chr1': 'chr1',
#  'chr2': 'chr1',
#  'count': 23,
#  'count.2': 23,
#  'end1': 10010000,
#  'end2': 10090000,
#  'expected': 11.019126676875802,
#  'expected.2': 9.36083378557571,
#  'fdr': 0.00913573738278233,
#  'fdr.2': 0.00510315858389689,
#  'start1': 10000000,
#  'start2': 10080000}
